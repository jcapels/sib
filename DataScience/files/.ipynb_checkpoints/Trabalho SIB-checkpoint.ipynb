# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

data = pd.read_csv("data_RNA_Seq_v2_expression_median.txt",sep="\t",index_col=0)
meta_patients = pd.read_csv("data_bcr_clinical_data_patient.txt",sep="\t",header=4)
meta_sample = pd.read_csv("data_bcr_clinical_data_sample.txt",sep="\t",header=4,index_col=1)



print(data.shape)
print(meta_patients.shape)
print(meta_sample.shape)
# Out:
# (20531, 518)
# (522, 80)
# (586, 25)

# %%
print(data.isnull().sum().sum())
print(meta_patients.isnull().sum().sum())
# Out:
# 0
# 0

# %%
sel_index=data.apply(lambda x: (x==0).all(), axis = 0)
sel_index.index[sel_index]
# Out:
# Index([], dtype='object')

# %%
data_scaled = preprocessing.scale(data.iloc[:,1:])

#data_scaled = np.column_stack((data.iloc[:,0],data_scaled))
data_scaled = pd.DataFrame(data_scaled, index =data.index , columns = data.columns[1:])
print(data_scaled.shape)
data_scaled.describe()
# Out:
# (20531, 517)
#        TCGA-05-4244-01  TCGA-05-4249-01  TCGA-05-4250-01  TCGA-05-4382-01  \
# count     2.053100e+04     2.053100e+04     2.053100e+04     2.053100e+04
# mean     -3.115773e-16    -1.279371e-16    -1.180710e-16     1.760426e-16
# std       1.000024e+00     1.000024e+00     1.000024e+00     1.000024e+00
# min      -2.379758e-01    -2.842081e-01    -2.626203e-01    -2.374016e-01
# 25%      -2.362731e-01    -2.821306e-01    -2.611826e-01    -2.352066e-01
# 50%      -1.869794e-01    -2.222808e-01    -2.078085e-01    -1.808513e-01
# 75%      -3.194700e-02    -2.393561e-02    -3.748754e-02    -2.688335e-02
# max       6.888929e+01     4.859775e+01     4.731961e+01     5.039623e+01
#
#        TCGA-05-4384-01  TCGA-05-4389-01  TCGA-05-4390-01  TCGA-05-4395-01  \
# count     2.053100e+04     2.053100e+04     2.053100e+04     2.053100e+04
# mean      1.639365e-16    -5.013876e-17    -1.044819e-16    -5.187187e-18
# ...

# %%
data_scaled.isnull().sum().sum()
# Out:
# 0

# %%
#the followig code verifies whether there is repeated patients identifier or not
patients_list = data_scaled.columns.tolist()
res = []
seen = []
for patient in patients_list:
    if patient in seen:
        res.append(patient)
    else:
        seen.append(patient)
print(res)
# Out:
# []

# %%
#replicar nos metadados os pacientes com 2 amostras
#retirar dos metadados os que não têm dados de expressao
meta_ids = meta_patients.loc[:,"PATIENT_ID"].tolist()
meta_ids = [ids+"-01" for ids in meta_ids]
data_ids = data_scaled.columns.tolist()
patients_without_expression_data = []
for ids in meta_ids:
    if ids not in data_ids:
        patients_without_expression_data.append(ids)
print(patients_without_expression_data)
patients_without_expression_data = [ ids[:-3] for ids in patients_without_expression_data]
print(patients_without_expression_data)

subset_meta = pd.DataFrame(meta_patients.loc[])
# Out:
# ['TCGA-05-4245-01', 'TCGA-44-2664-01', 'TCGA-44-3917-01', 'TCGA-44-6144-01', 'TCGA-44-A47F-01', 'TCGA-67-3776-01', 'TCGA-MP-A4T2-01']
# ['TCGA-05-4245', 'TCGA-44-2664', 'TCGA-44-3917', 'TCGA-44-6144', 'TCGA-44-A47F', 'TCGA-67-3776', 'TCGA-MP-A4T2']

# %%
sel_index=meta.apply(lambda x: (x=="[Not Available]").all(), axis = 0)
sel_index[sel_index==True]
# Out:
# LATERALITY                                    True
# METHOD_OF_INITIAL_SAMPLE_PROCUREMENT          True
# METHOD_OF_INITIAL_SAMPLE_PROCUREMENT_OTHER    True
# PHARMACEUTICAL_TX_ADJUVANT                    True
# DAYS_TO_PATIENT_PROGRESSION_FREE              True
# DAYS_TO_TUMOR_PROGRESSION                     True
# ALK_TRANSLOCATION_VARIANT                     True
# HISTORY_IMMUNOLOGICAL_DISEASE                 True
# HISTORY_IMMUNOLOGICAL_DISEASE_OTHER           True
# HISTORY_RELEVANT_INFECTIOUS_DX                True
# HIV_STATUS                                    True
# NUMBER_OF_LYMPHNODES_POSITIVE_BY_IHC          True
# POS_LYMPH_NODE_LOCATION                       True
# STAGE_OTHER                                   True
# dtype: bool
